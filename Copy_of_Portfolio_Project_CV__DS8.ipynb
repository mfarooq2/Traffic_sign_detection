# %% [markdown]
# # Traffic Signs Detection using YOLOv8 (custom training)

# %% [markdown]
# Computer vision is a field of artificial intelligence that focuses on teaching computers to interpret and understand visual information. One popular and powerful technique used in computer vision for object detection is called YOLO, which stands for "You Only Look Once".
#
# YOLO aims to identify and locate objects in an image or video stream in real-time. Unlike traditional methods that rely on complex pipelines and multiple passes, YOLO takes a different approach by treating object detection as a single regression problem.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. Description:
# We have already covered background of YOLOv8, it’s different features and arguments in class. We also performed inference on test image and video to check and compare accuracy and many other factors such as speed, no. layers, no. of parameters etc of YOLOn, YOLOs & YOLOm.

# %% [markdown]
# ### 3. 	Problem Statement:
# In Autonomous car driving there are many modules such as:
#
# - Lane Detection
# - Object Avoidance
# - Traffic signs Detection
#
# #### In this Portfolio Project you’re expected to train YOLOv8 on custom dataset and run inference by detecting Traffic Signs images.

# %% [markdown]
# ### 4.	Instructions:
# 1. Use Google Colab with runtime as T4GPU.

# %% [markdown]
# 2. Import all the necessary libraries including  Ultralytics and image visualization

# %% [markdown]
# 3. Choose a suitable dataset with Traffic signs images either from Kaggle or Roboflow
#
# https://universe.roboflow.com/search?q=german%2520traffic%2520sign
# https://www.kaggle.com/datasets/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign
#
# - Imp Note: (Use API Key to directly use Traffic Signs Detection dataset in Colab Notebook)
# - Do not choose a very large dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VPemMt8i4T7N9s6UJUDl")
project = rf.workspace("fsevval").project("traffic-sign-guy19")
version = project.version(1)
dataset = version.download("yolov8")

# %% [markdown]
# 4. Display the images to check whether dataset has been correctly uploaded or not
# - Define the directory containing images
# - Set the number of samples to display
# - Get the list of all image files in the directory
# - Randomly select num_samples images
# - Create a 3x3 subplot
# - Loop through each randomly selected image and display it

# %% [markdown]
# Output should be sth like this
#
# ![image.png](data:image/png;base64,...)

# %%
# !pip install --upgrade ultralytics ray

# %% [markdown]
# 5. Download YOLOv8 and run Inference on a random image with Traffic signs

# %% [markdown]
# ### 6. Now train YOLOv8 on Custom data

# %%
# !pip install ray[tune] --upgrade
# use latest version library otherwise error will come during training

# %% [markdown]
# Do all the neccesary steps to check inference and check accuracy.

# %% [markdown]
# ## CONCLUSION:
# 1. You have learned how to finetune a State of the Art Model like YOLO according to your specific problem.
# 2. Working on custom dataset
# 3. How to use API

# %% [markdown]
# ## Resource:
# https://www.kaggle.com/code/pkdarabi/traffic-signs-detection-using-yolov8#4-%7C-Try-Pre-trained-YOLOv8-For-Detect-Traffic-Signs--
